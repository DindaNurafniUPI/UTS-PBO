# %%
print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
print('SELAMAT DATANG PENGUNJUNG SAVE MONEY DIGITAL')
print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
print(' ')
print(' ==Pilih Menu== ')
print('1. Informasi Saldo')
print('2. Tambah Saldo')
print('3. Ambil saldo ')
print('4. Keluar')
print(' ')
option=int(input('silahkan pilih menu anda = '))
uangda=0
if option==1:
    print('Saldo umum Rp.0,')
    print('saldo tabungan = Rp.0,')
elif option==2:
    print('Pilih menu option anda')
    print('1. Umum')
    print('2. Tabungan')
    option2=int(input('Silahkan masukan option anda'))
    if option2==1:
        print('Masukan keterangan anda')
        uang1=int(input('masukan nominal anda = '))
        hasil=uang1+uangda
        print('saldo umum anda = ', hasil)
    elif option2==2:
        print('Masukan keterangan anda')
        uang2=int(input('masukan nominal anda = '))
        hasil2=uang2+uangda
        print('saldo tabungan anda = ',hasil2)
    else:
        print('Masukan input option yang benar!')
elif option==3:
    print('Pilih menu option anda')
    print('1. Umum')
    print('2. Tabungan')
    option3=int(input('Silahkan masukan option anda'))
    if option3==1:
        kur=int(input('jumlah tarik tunai (*min 10.000)'))
        kurang=hasil-kur
        print('saldo anda sekarang ',kurang)
    elif option3==2:
        kur2=int(input('jumlah tarik tunai (*min 10.000)'))
        kurang2=hasil2-kur2
        print('saldo anda sekarang ',kurang2)
    else:
        print('Masukan input option yang benar!')
elif option==4:
    import sys
    import time
    
    print('Terimakasih')
    time.sleep(2)
    sys.exit()
else:
    print('mohon masukan perintah input option yang sesuai')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# SELAMAT DATANG PENGUNJUNG SAVE MONEY DIGITAL
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  ==Pilih Menu==
# 1. Informasi Saldo
# 2. Tambah Saldo
# 3. Ambil saldo
# 4. Keluar
#
# silahkan pilih menu anda = 2
# Pilih menu option anda
# 1. Umum
# 2. Tabungan
# Silahkan masukan option anda2
# Masukan keterangan anda
# masukan nominal anda = 600000
# saldo tabungan anda =  600000

# %% [markdown]
# #

# %%
print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
print('SELAMAT DATANG PENGUNJUNG SAVE MONEY DIGITAL')
print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
print(' ')
print(' ==Pilih Menu== ')
print('1. Informasi Saldo')
print('2. Tambah Saldo')
print('3. Ambil saldo ')
print('4. Keluar')
print(' ')
option=int(input('silahkan pilih menu anda = '))
uangda=0
if option==1:
    print('Saldo umum Rp.0,')
    print('saldo tabungan = Rp.0,')
elif option==2:
    print('Pilih menu option anda')
    print('1. Umum')
    print('2. Tabungan')
    option2=int(input('Silahkan masukan option anda'))
    if option2==1:
        print('Masukan keterangan anda')
        uang1=int(input('masukan nominal anda = '))
        hasil=uang1+uangda
        print('saldo umum anda = ', hasil)
    elif option2==2:
        print('Masukan keterangan anda')
        uang2=int(input('masukan nominal anda = '))
        hasil2=uang2+uangda
        print('saldo tabungan anda = ',hasil2)
    else:
        print('Masukan input option yang benar!')
elif option==3:
    print('Pilih menu option anda')
    print('1. Umum')
    print('2. Tabungan')
    option3=int(input('Silahkan masukan option anda'))
    if option3==1:
        kur=int(input('jumlah tarik tunai (*min 10.000)'))
        kurang=hasil-kur
        print('saldo anda sekarang ',kurang)
    elif option3==2:
        kur2=int(input('jumlah tarik tunai (*min 10.000)'))
        kurang2=hasil2-kur2
        print('saldo anda sekarang ',kurang2)
    else:
        print('Masukan input option yang benar!')
elif option==4:
    import sys
    import time
    
    print('Terimakasih')
    time.sleep(2)
    sys.exit()
else:
    print('mohon masukan perintah input option yang sesuai')
    
    
        
    




bank=Bank()
while True:
    userchoice1 = user_choice1()
    if userchoice1 == "1":
        bank.create_account()
        if not previous_page():
            break
        else:
            continue
    elif userchoice1 == "2": 
        bank.access_account()     
        while True:
            userchoice2 = user_choice2()
            if userchoice2 == "1":
                bank.display_balance()
                if not previous_page():
                    break
                else:
                    continue 
            elif userchoice2=="2":   
                bank.withdraw_money()   
                if not previous_page():
                    break
                else:
                    continue 
            elif userchoice2=="3":
                bank.deposit_money()
                if not previous_page():
                    break
                else:
                    continue
            elif userchoice2=="4":
                break
    else:
        break

print ("Thankyou for using the bank!")
